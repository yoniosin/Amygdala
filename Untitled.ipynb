# %%
from matplotlib import pyplot as plt
import numpy as np
import json
import re

# %%
embeddings = np.load('TSNE_80.ny')

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.scatter(embeddings[:, 0], embeddings[:, 1])

plt.show()

# %% [markdown]
# # Get Subjects' Analytocal score

# %%
score_vec = json.load(open('score_vec.json'))

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
image = ax.scatter(embeddings[:, 0], embeddings[:, 1], c= list(range(87)))
fig.colorbar(image, ax=ax)
plt.show()
