# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
embeddings = np.load('TSNE.ny')

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.scatter(embeddings[:, 0], embeddings[:, 1])

plt.show()
